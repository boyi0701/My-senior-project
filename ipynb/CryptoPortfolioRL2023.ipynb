# %% [markdown]
# # 實驗說明
#
# ## 歷史幣價資料取得
#
# - [幣安API](https://binance-docs.github.io/apidocs/futures/cn/#185368440e)
#
# ## 幣種
#
# - BTC
# - ETH
# - BNB
# - SOL
# - BUSD
#
# ## 資料切分
#
# - 訓練時間段 : 2020/10/17 ~ 2021/10/17
# - 測試時間段 : 2021/10/18 ~ 2023/10/25
#
# ## 避險機制
#
# #### 邏輯
# - 比特幣做為加密貨幣的元老，其走勢往往能牽動其他的加密貨幣，例如比特幣大漲時會帶動其他小幣可能一起漲，甚至漲得更多，但比特幣大跌時同樣也會讓其他小幣一起大跌，如同加密貨幣的大盤
#
# #### 原理
# - 利用比特幣的大盤特性計算一種動能指標來判斷當前市場是樂觀情緒(利於做多)還是悲觀情緒(不利於做多)
#
# - 在比特幣動能<0時判定為不利於做多的市場，將所有幣種賣出並轉換成穩定幣以度過進一步下跌風險
# - 在比特幣動能>0後判定為利於做多的市場，再將穩定幣換成各個幣種以吃到瞬間漲幅
#
# ## 特徵
# - [眾多技術指標](https://github.com/bukosabino/ta)
# - [SuperTrend](https://tw.tradingview.com/scripts/supertrend/) 指標
# - [Catch22](https://github.com/DynamicsAndNeuralSystems/pycatch22) 時間序列特徵
# - 過去平均跌幅
# - 微軟[QLib](https://github.com/microsoft/qlib) 開高低收特徵
#
# ## 模型
# - 強化學習演算法 [A2C](https://github.com/openai/baselines/tree/master/baselines/a2c)
#
# ## 回測結果分析
#
# - 比較基準為100%持有比特幣
#
# #### 重要的衡量指標
# - Alpha : 相對於大盤(比特幣)的超額報酬，愈高愈好，表示無考慮風險的賺錢能力
# - Sharp Ratio : 承受一單位的風險可以獲得多少單位的報酬，愈高愈好，表示有考慮風險的賺錢能力
# - CAGR : 年複合增長率，平均一年成長了多少%，愈高愈好
# - Calmar Ratio : CAGR/Max Drawdown，愈高愈好，表示考慮最大風險的賺錢能力
# - Mean Drawdown : 平均跌幅，愈低愈好，表示一期間內平均跌了多少%，表示抗跌能力
# - Max Drawdown : 最大跌幅，愈低愈好，表示曾經跌了多少%
# - Prob of Losing Money : 一期間內虧錢期間佔了多少%，愈低愈好，表示虧錢期間的長短
#
# #### 從報酬的角度來看
# - 2021年末的短暫牛市報酬大於單純持有比特幣
# - 2023年比特幣從低點反彈並有幾段牛市，因此模型表現不如單純持有比特幣
# - 2021/10/18~2023/10/25 獲利表現 44% 勝單純持有比特幣的-43%
#
# #### 從風險的角度來看
# - 2022年熊市可以透過避險機制避開數次大跌，跌幅遠低於單純持有比特幣
# - 最大回撤 -41% 勝單純持有比特幣的76%
# - 平均回撤 -17% 勝單純持有比特幣的55%
#
# ## 結論
#
# - 長期持有加密貨幣是一件高風險高報酬的事情，例如單純持有比特幣，雖然上漲時漲幅高，但下跌時跌幅也很高，並且很依靠進場的位置，是否屬於低點。本研究使用A2C強化學習模型並配合避險機制風控一個長期持有加密貨幣的投資組合，實驗結果表明可以在報酬與風險中間達到一個不錯的平衡，為投資人提供一個除了單純持有比特幣以外的新選擇。

# %% [markdown]
# # 連結雲端硬碟

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 安裝套件

# %%
# !pip install stable-baselines3==1.2.0 > log.txt
# !pip install optuna > log.txt
# !pip install ta==0.9.0 > log.txt
# !pip install git+https://github.com/DynamicsAndNeuralSystems/pycatch22.git
# Install ta-lib
url = 'https://launchpad.net/~mario-mariomedina/+archive/ubuntu/talib/+files'
# !wget $url/libta-lib0_0.4.0-oneiric1_amd64.deb -qO libta.deb
# !wget $url/ta-lib0-dev_0.4.0-oneiric1_amd64.deb -qO ta.deb
# !dpkg -i libta.deb ta.deb
# !pip install ta-lib > log.txt
# Out:
# Collecting git+https://github.com/DynamicsAndNeuralSystems/pycatch22.git
#   Cloning https://github.com/DynamicsAndNeuralSystems/pycatch22.git to /tmp/pip-req-build-sxjgwljw
#   Running command git clone --filter=blob:none --quiet https://github.com/DynamicsAndNeuralSystems/pycatch22.git /tmp/pip-req-build-sxjgwljw
#   Resolved https://github.com/DynamicsAndNeuralSystems/pycatch22.git to commit e3c35713dcf35fb97a6eae0271fb417d2db0ec1f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# (Reading database ... 121944 files and directories currently installed.)
# Preparing to unpack libta.deb ...
# Unpacking libta-lib0 (0.4.0-oneiric1) over (0.4.0-oneiric1) ...
# Preparing to unpack ta.deb ...
# Unpacking ta-lib0-dev (0.4.0-oneiric1) over (0.4.0-oneiric1) ...
# Setting up libta-lib0 (0.4.0-oneiric1) ...
# Setting up ta-lib0-dev (0.4.0-oneiric1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link

# %% [markdown]
# *斜體文字*# 設定參數

# %%
# 雲端硬碟檔案存放路徑
FOLDER = '/content/drive/MyDrive/CryptoPortfolioRL2023/'

# 設定回測比較基準，如比特幣
BENCHMARK = 'BTC/USDT'

# 一開始的投資金額
INITIAL_AMOUNT = 10000

# 訓練回合數
N_TIMESTEPS = 50000

# 是否使用避險機制 : [True] [False]
HEDGING = [True]

# 模型演算法選擇 : 'a2c' 'ppo'
AGENT_NAME = 'ppo'

# 模型超參數
A2C_PARAMS = {"n_steps": 5, "ent_coef": 0.005, "learning_rate": 0.002}
PPO_PARAMS = {"n_steps": 2048,"ent_coef": 0.005,"learning_rate": 0.001,"batch_size": 128}

MODEL_KWARGS = {"a2c": A2C_PARAMS, "ppo": PPO_PARAMS}

# 訓練與測試時間段
TRAIN_START_DATE = '2020-10-17'
TRAIN_END_DATE = '2021-10-17'
TRADE_START_DATE = '2021-10-18'
TRADE_END_DATE = '2023-10-25'

# 投資組合中的加密貨幣
CRYPTO_LIST = ['BTC', 'ETH', 'BNB', 'SOL']

# 加入所有特徵 (預設)
FEATURE_LIST = ['86ta', 'dd', 'st', 'catch22', 'qlib']

if HEDGING[0]:
    CRYPTO_LIST.append('BUSD')
    FEATURE_LIST.append('hedging')

    index_busd = sorted(CRYPTO_LIST).index('BUSD')
    HEDGING.append(index_busd)

CRYPTO_LIST = [ticker + '/USDT' for ticker in CRYPTO_LIST]

# %% [markdown]
# [連結文字](https://)# 資料、環境建置、模型訓練

# %%
from data import *

data_kwargs = {
    "folder": FOLDER,
    "crypto_list": CRYPTO_LIST,
    "feature_list": FEATURE_LIST,
    "train_start_date": TRAIN_START_DATE,
    "train_end_date": TRAIN_END_DATE,
    "trade_start_date": TRADE_START_DATE,
    "trade_end_date": TRADE_END_DATE
}
# 讀取、計算特徵、並切分成訓練、測試資料
train, trade, tech_indicator_list = prepare_data(**data_kwargs)

from training import *

env_kwargs = {
    "transaction_cost_pct": 0.001,
    "reward_scaling": 1e-4,
    "initial_amount": INITIAL_AMOUNT,
    "tech_indicator_list": tech_indicator_list,
    "hedging": HEDGING,
    "folder": FOLDER
}
# 建立強化學習的環境
e_train_gym, e_trade_gym, env_train, crypto_dimension, state_space = building_environment(env_kwargs, train, trade)

train_kwargs = {
    "train": train,
    "trade": trade,
    "e_train_gym": e_train_gym,
    "e_trade_gym": e_trade_gym,
    "env_train": env_train,
    "agent_name": AGENT_NAME,
    "total_timesteps":N_TIMESTEPS,
    "MODEL_KWARGS": MODEL_KWARGS,
    "folder": FOLDER
}
# 訓練模型，並讓模型預測測試時間段的結果
df_daily_return, df_actions, trained_agent = train_test_agent(**train_kwargs)
# Out:
# Crypto Dimension: 5, State Space: 5
# reset at 2020-10-17T08:00:00.000000000
# reset at 2021-10-18T08:00:00.000000000
# {'n_steps': 2048, 'ent_coef': 0.005, 'learning_rate': 0.001, 'batch_size': 128}
# Using cpu device
# reset at 2020-10-17T08:00:00.000000000
# Logging to ./ppo/ppo_1
# =================================
# begin_total_asset:10000
# end_total_asset:150433.72796306154
# Sharpe:  0.22568150771049467
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:136709.96555826176
# Sharpe:  0.2195797051393616
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:110925.00842095552
# Sharpe:  0.20378156200174194
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:149932.33899116144
# Sharpe:  0.22560005393735277
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:129418.69240836619
# Sharpe:  0.20869640089891217
# =================================
# reset at 2020-10-17T08:00:00.000000000
# -----------------------------
# | time/              |      |
# |    fps             | 32   |
# |    iterations      | 1    |
# |    time_elapsed    | 62   |
# |    total_timesteps | 2048 |
# -----------------------------
# =================================
# begin_total_asset:10000
# end_total_asset:150308.06708012283
# Sharpe:  0.2252316964713914
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:158970.97247601798
# Sharpe:  0.22821969729610325
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:133179.13432716497
# Sharpe:  0.21903009337271928
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:167501.69598184738
# Sharpe:  0.22786954545575364
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:126803.1942497161
# Sharpe:  0.2144157744891224
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:120432.97594868772
# Sharpe:  0.21299669742841726
# =================================
# reset at 2020-10-17T08:00:00.000000000
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 2            |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 8.359784e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.09        |
# |    explained_variance   | -3.58e-07    |
# |    learning_rate        | 0.001        |
# |    loss                 | 6.14e+11     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -7.89e-05    |
# |    std                  | 1            |
# |    value_loss           | 1.23e+12     |
# ------------------------------------------
# =================================
# begin_total_asset:10000
# end_total_asset:139441.77412490512
# Sharpe:  0.22229683765155636
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:132481.84527536674
# Sharpe:  0.21440700580332098
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:146615.9570842866
# Sharpe:  0.22428752774804728
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:138240.0274291865
# Sharpe:  0.21914395244761672
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:134362.92083705153
# Sharpe:  0.21596172716614193
# =================================
# reset at 2020-10-17T08:00:00.000000000
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 32            |
# |    iterations           | 3             |
# |    time_elapsed         | 187           |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 1.2110104e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | 8.52e-06      |
# |    learning_rate        | 0.001         |
# |    loss                 | 7.64e+11      |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -2.36e-05     |
# |    std                  | 1             |
# |    value_loss           | 1.53e+12      |
# -------------------------------------------
# =================================
# begin_total_asset:10000
# end_total_asset:133166.40996288272
# Sharpe:  0.21059093152921737
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:136165.9296346531
# Sharpe:  0.21624507562127843
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:139676.42580944454
# Sharpe:  0.2202637873180088
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:127895.86751748242
# Sharpe:  0.21361667894247868
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:134927.22832861487
# Sharpe:  0.2176481357449589
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:129362.55703032184
# Sharpe:  0.21349902661941356
# =================================
# reset at 2020-10-17T08:00:00.000000000
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 32            |
# |    iterations           | 4             |
# |    time_elapsed         | 249           |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 2.7680653e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | 1.07e-05      |
# |    learning_rate        | 0.001         |
# |    loss                 | 6.64e+11      |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -3.44e-05     |
# |    std                  | 1             |
# |    value_loss           | 1.31e+12      |
# -------------------------------------------
# =================================
# begin_total_asset:10000
# end_total_asset:152832.35352118107
# Sharpe:  0.22327418560912296
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:139228.54385261718
# Sharpe:  0.2139148721468265
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:116383.74502365831
# Sharpe:  0.20759824876694616
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:129036.91900462078
# Sharpe:  0.21319964677269246
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:119359.11242107801
# Sharpe:  0.2094560825811379
# =================================
# reset at 2020-10-17T08:00:00.000000000
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 32            |
# |    iterations           | 5             |
# |    time_elapsed         | 311           |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 3.3646938e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | 1.13e-05      |
# |    learning_rate        | 0.001         |
# |    loss                 | 6.08e+11      |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -4.62e-05     |
# |    std                  | 1             |
# |    value_loss           | 1.28e+12      |
# -------------------------------------------
# =================================
# begin_total_asset:10000
# end_total_asset:133049.12275124688
# Sharpe:  0.2183081579738069
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:127634.04742054598
# Sharpe:  0.21853046633777135
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:157062.5037831379
# Sharpe:  0.22937302902378712
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:122889.68738203867
# Sharpe:  0.20915826826741044
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:164748.76854898938
# Sharpe:  0.23213689910599145
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:135243.4976968762
# Sharpe:  0.22120434382078832
# =================================
# reset at 2020-10-17T08:00:00.000000000
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 33            |
# |    iterations           | 6             |
# |    time_elapsed         | 371           |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 2.5561894e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | 1.06e-05      |
# |    learning_rate        | 0.001         |
# |    loss                 | 6.72e+11      |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -4.31e-05     |
# |    std                  | 1             |
# |    value_loss           | 1.35e+12      |
# -------------------------------------------
# =================================
# begin_total_asset:10000
# end_total_asset:164866.42613465758
# Sharpe:  0.22897250665118407
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:132918.42806648262
# Sharpe:  0.21609881885562182
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:111788.35896445112
# Sharpe:  0.20550516614413794
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:139358.9638792486
# Sharpe:  0.22176913746047505
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:143702.99636668147
# Sharpe:  0.21895122446443538
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:157782.06638263992
# Sharpe:  0.22643701841250455
# =================================
# reset at 2020-10-17T08:00:00.000000000
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 33           |
# |    iterations           | 7            |
# |    time_elapsed         | 433          |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 2.764864e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.09        |
# |    explained_variance   | 1.07e-05     |
# |    learning_rate        | 0.001        |
# |    loss                 | 6.97e+11     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -3.84e-05    |
# |    std                  | 1            |
# |    value_loss           | 1.34e+12     |
# ------------------------------------------
# =================================
# begin_total_asset:10000
# end_total_asset:126434.73005260501
# Sharpe:  0.2123027253746414
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:135101.7436603701
# Sharpe:  0.21775570865601754
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:127799.90511318573
# Sharpe:  0.21450641793192285
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:171899.85344555063
# Sharpe:  0.23236078906671373
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:119510.48445409014
# Sharpe:  0.21567542050058092
# =================================
# reset at 2020-10-17T08:00:00.000000000
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 32            |
# |    iterations           | 8             |
# |    time_elapsed         | 496           |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 6.1650644e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | 1.02e-05      |
# |    learning_rate        | 0.001         |
# |    loss                 | 6.74e+11      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -7.11e-05     |
# |    std                  | 1             |
# |    value_loss           | 1.43e+12      |
# -------------------------------------------
# =================================
# begin_total_asset:10000
# end_total_asset:170912.5877436998
# Sharpe:  0.22588858626118008
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:182296.95729729367
# Sharpe:  0.23776179169807019
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:146659.466655654
# Sharpe:  0.22212456287157598
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:130457.24993013167
# Sharpe:  0.21188760348124142
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:133281.12212479883
# Sharpe:  0.21173035948162738
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:131776.67940731434
# Sharpe:  0.21496309415243947
# =================================
# reset at 2020-10-17T08:00:00.000000000
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 33            |
# |    iterations           | 9             |
# |    time_elapsed         | 557           |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 2.0081643e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | 9.89e-06      |
# |    learning_rate        | 0.001         |
# |    loss                 | 6.54e+11      |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -3.08e-05     |
# |    std                  | 1             |
# |    value_loss           | 1.3e+12       |
# -------------------------------------------
# =================================
# begin_total_asset:10000
# end_total_asset:145136.6494048985
# Sharpe:  0.22011823950123202
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:146886.80460181626
# Sharpe:  0.22344011424374619
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:131555.23585768178
# Sharpe:  0.21425240564245562
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:106962.58130426407
# Sharpe:  0.20061725236638112
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:155930.66549489324
# Sharpe:  0.22623200432754248
# =================================
# reset at 2020-10-17T08:00:00.000000000
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 33           |
# |    iterations           | 10           |
# |    time_elapsed         | 620          |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 5.241018e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.09        |
# |    explained_variance   | 9.06e-06     |
# |    learning_rate        | 0.001        |
# |    loss                 | 7.74e+11     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -6.38e-05    |
# |    std                  | 1            |
# |    value_loss           | 1.55e+12     |
# ------------------------------------------
# =================================
# begin_total_asset:10000
# end_total_asset:114540.95017939011
# Sharpe:  0.20931843370370762
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:146371.3202254373
# Sharpe:  0.22666021221088672
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:126508.07685716717
# Sharpe:  0.21718138492861164
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:135477.68048052836
# Sharpe:  0.21840043583976315
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:116111.51719158814
# Sharpe:  0.20698083868270487
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:158061.1402179177
# Sharpe:  0.23055561854282786
# =================================
# reset at 2020-10-17T08:00:00.000000000
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 33            |
# |    iterations           | 11            |
# |    time_elapsed         | 681           |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 3.7095742e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | 8.94e-06      |
# |    learning_rate        | 0.001         |
# |    loss                 | 6.69e+11      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -5.31e-05     |
# |    std                  | 1             |
# |    value_loss           | 1.37e+12      |
# -------------------------------------------
# =================================
# begin_total_asset:10000
# end_total_asset:121706.05570300698
# Sharpe:  0.2098378883170512
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:121771.38353572976
# Sharpe:  0.20964781089244985
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:130037.95101893182
# Sharpe:  0.21712394463733836
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:121418.4902862144
# Sharpe:  0.21489422924892534
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:140261.7492523201
# Sharpe:  0.2205882463474958
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:136637.31319823547
# Sharpe:  0.2184122298227673
# =================================
# reset at 2020-10-17T08:00:00.000000000
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 33            |
# |    iterations           | 12            |
# |    time_elapsed         | 743           |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 2.6804628e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.1          |
# |    explained_variance   | 9.24e-06      |
# |    learning_rate        | 0.001         |
# |    loss                 | 5.74e+11      |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -3.59e-05     |
# |    std                  | 1             |
# |    value_loss           | 1.24e+12      |
# -------------------------------------------
# =================================
# begin_total_asset:10000
# end_total_asset:126342.65271500962
# Sharpe:  0.2158713995758539
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:145644.78378211695
# Sharpe:  0.22571040874703674
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:130200.81731496654
# Sharpe:  0.21904963280714004
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:170761.37258897375
# Sharpe:  0.23692149377178748
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:124898.80777607425
# Sharpe:  0.20978701081202922
# =================================
# reset at 2020-10-17T08:00:00.000000000
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 32            |
# |    iterations           | 13            |
# |    time_elapsed         | 809           |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 2.6234193e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.1          |
# |    explained_variance   | 9.18e-06      |
# |    learning_rate        | 0.001         |
# |    loss                 | 6.03e+11      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -3.65e-05     |
# |    std                  | 1             |
# |    value_loss           | 1.22e+12      |
# -------------------------------------------
# =================================
# begin_total_asset:10000
# end_total_asset:121535.63234990566
# Sharpe:  0.21504702185995578
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:152465.7938071686
# Sharpe:  0.22695938009748468
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:122566.63817870524
# Sharpe:  0.2120229051605852
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:157502.53606884138
# Sharpe:  0.22565912040027847
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:124874.97223816364
# Sharpe:  0.21240056833357077
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:149683.34479299522
# Sharpe:  0.22205195027364716
# =================================
# reset at 2020-10-17T08:00:00.000000000
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 32            |
# |    iterations           | 14            |
# |    time_elapsed         | 870           |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 1.1725933e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.1          |
# |    explained_variance   | 6.56e-06      |
# |    learning_rate        | 0.001         |
# |    loss                 | 6.7e+11       |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -2.43e-05     |
# |    std                  | 1             |
# |    value_loss           | 1.31e+12      |
# -------------------------------------------
# =================================
# begin_total_asset:10000
# end_total_asset:129521.93845515365
# Sharpe:  0.20940886900373365
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:116785.83465082564
# Sharpe:  0.20618442691280436
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:135459.0030278373
# Sharpe:  0.21629343896566186
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:120987.78216459764
# Sharpe:  0.20754972577842162
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:130549.38356428668
# Sharpe:  0.21458550190987077
# =================================
# reset at 2020-10-17T08:00:00.000000000
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 33            |
# |    iterations           | 15            |
# |    time_elapsed         | 929           |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 2.7386704e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.1          |
# |    explained_variance   | 6.68e-06      |
# |    learning_rate        | 0.001         |
# |    loss                 | 7.39e+11      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -3.8e-05      |
# |    std                  | 1             |
# |    value_loss           | 1.33e+12      |
# -------------------------------------------
# =================================
# begin_total_asset:10000
# end_total_asset:135677.39907787077
# Sharpe:  0.22158544814605804
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:131048.17816697243
# Sharpe:  0.21328652383086347
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:121035.29603133528
# Sharpe:  0.20849117178199278
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:131242.0684632243
# Sharpe:  0.21525840134437652
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:159705.17177243187
# Sharpe:  0.22634927284656184
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:110437.4400892816
# Sharpe:  0.2074948351862946
# =================================
# reset at 2020-10-17T08:00:00.000000000
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 32            |
# |    iterations           | 16            |
# |    time_elapsed         | 994           |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 3.2089883e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.1          |
# |    explained_variance   | 6.32e-06      |
# |    learning_rate        | 0.001         |
# |    loss                 | 6.7e+11       |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -4.1e-05      |
# |    std                  | 1             |
# |    value_loss           | 1.24e+12      |
# -------------------------------------------
# =================================
# begin_total_asset:10000
# end_total_asset:132090.3149217975
# Sharpe:  0.21601140543330133
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:133440.48679799016
# Sharpe:  0.21526730702609637
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:133226.39254525382
# Sharpe:  0.2182841417780254
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:154286.17407613684
# Sharpe:  0.22818753331456573
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:145547.50482797934
# Sharpe:  0.22178272235131616
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:153360.3028473657
# Sharpe:  0.2229039237773104
# =================================
# reset at 2020-10-17T08:00:00.000000000
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 32            |
# |    iterations           | 17            |
# |    time_elapsed         | 1056          |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 5.0343806e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.1          |
# |    explained_variance   | 5.19e-06      |
# |    learning_rate        | 0.001         |
# |    loss                 | 7.12e+11      |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -5.42e-05     |
# |    std                  | 1             |
# |    value_loss           | 1.21e+12      |
# -------------------------------------------
# =================================
# begin_total_asset:10000
# end_total_asset:138744.0424709255
# Sharpe:  0.21710924603575027
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:119853.64061745968
# Sharpe:  0.20810060768799948
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:138617.39309079945
# Sharpe:  0.2198156637070286
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:117965.46884843647
# Sharpe:  0.20523836891837322
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:123973.19462587032
# Sharpe:  0.2172660306921774
# =================================
# reset at 2020-10-17T08:00:00.000000000
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 18           |
# |    time_elapsed         | 1117         |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 8.411007e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.1         |
# |    explained_variance   | 4.59e-06     |
# |    learning_rate        | 0.001        |
# |    loss                 | 7.81e+11     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -1.81e-05    |
# |    std                  | 1            |
# |    value_loss           | 1.5e+12      |
# ------------------------------------------
# =================================
# begin_total_asset:10000
# end_total_asset:140065.7159758831
# Sharpe:  0.22052753451458826
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:136743.2767274991
# Sharpe:  0.22167186690099547
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:127741.43014315513
# Sharpe:  0.2158010422330793
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:132768.60458117345
# Sharpe:  0.21907228841218856
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:145617.30994361828
# Sharpe:  0.22303115805586216
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:119774.43004614154
# Sharpe:  0.21247432399643632
# =================================
# reset at 2020-10-17T08:00:00.000000000
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 19           |
# |    time_elapsed         | 1180         |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 2.135348e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.1         |
# |    explained_variance   | 4.29e-06     |
# |    learning_rate        | 0.001        |
# |    loss                 | 5.88e+11     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -3.39e-05    |
# |    std                  | 1            |
# |    value_loss           | 1.18e+12     |
# ------------------------------------------
# =================================
# begin_total_asset:10000
# end_total_asset:151925.11076679907
# Sharpe:  0.23304944042547993
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:134005.811819419
# Sharpe:  0.21960823634466
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:128955.06736200796
# Sharpe:  0.2148201500648348
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:124709.67872998456
# Sharpe:  0.2109937689148499
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:126784.93670186054
# Sharpe:  0.21281976071073694
# =================================
# reset at 2020-10-17T08:00:00.000000000
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 32            |
# |    iterations           | 20            |
# |    time_elapsed         | 1243          |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 3.0378578e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.1          |
# |    explained_variance   | 3.64e-06      |
# |    learning_rate        | 0.001         |
# |    loss                 | 5.87e+11      |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -4.1e-05      |
# |    std                  | 1             |
# |    value_loss           | 1.28e+12      |
# -------------------------------------------
# =================================
# begin_total_asset:10000
# end_total_asset:156324.5763456627
# Sharpe:  0.22558889035910612
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:125019.02547539723
# Sharpe:  0.211142207227561
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:128891.22520773906
# Sharpe:  0.21495436003352184
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:135410.3577471579
# Sharpe:  0.21666755751440223
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:145697.67525016156
# Sharpe:  0.22310073878544956
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:135805.10115736077
# Sharpe:  0.21858065651204836
# =================================
# reset at 2020-10-17T08:00:00.000000000
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 33           |
# |    iterations           | 21           |
# |    time_elapsed         | 1301         |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 8.093775e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.1         |
# |    explained_variance   | 2.98e-06     |
# |    learning_rate        | 0.001        |
# |    loss                 | 7.47e+11     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -1.77e-05    |
# |    std                  | 1            |
# |    value_loss           | 1.39e+12     |
# ------------------------------------------
# =================================
# begin_total_asset:10000
# end_total_asset:132387.83022092594
# Sharpe:  0.2148426170305213
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:135686.81989379067
# Sharpe:  0.21955260601390766
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:116358.27810149439
# Sharpe:  0.20636247771659788
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:144088.7025197742
# Sharpe:  0.22153930461271182
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:146162.04130506495
# Sharpe:  0.22587757726598617
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:147469.4261016097
# Sharpe:  0.22454217216676672
# =================================
# reset at 2020-10-17T08:00:00.000000000
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 32            |
# |    iterations           | 22            |
# |    time_elapsed         | 1366          |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 3.1467061e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.1          |
# |    explained_variance   | 3.16e-06      |
# |    learning_rate        | 0.001         |
# |    loss                 | 5.99e+11      |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -4.7e-05      |
# |    std                  | 1             |
# |    value_loss           | 1.22e+12      |
# -------------------------------------------
# =================================
# begin_total_asset:10000
# end_total_asset:146097.71251869516
# Sharpe:  0.2212842150927902
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:158454.06119780315
# Sharpe:  0.22871333356930795
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:156208.49493531714
# Sharpe:  0.2255270565872953
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:126029.8315010992
# Sharpe:  0.21161352783372545
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:120788.64910208539
# Sharpe:  0.20897899006279447
# =================================
# reset at 2020-10-17T08:00:00.000000000
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 33            |
# |    iterations           | 23            |
# |    time_elapsed         | 1425          |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 2.1781307e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.1          |
# |    explained_variance   | 2.68e-06      |
# |    learning_rate        | 0.001         |
# |    loss                 | 7.13e+11      |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -4.09e-05     |
# |    std                  | 1             |
# |    value_loss           | 1.39e+12      |
# -------------------------------------------
# =================================
# begin_total_asset:10000
# end_total_asset:140682.9838130885
# Sharpe:  0.22128827472769405
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:141677.99629569726
# Sharpe:  0.22212016971849996
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:135603.50886729706
# Sharpe:  0.21713483357736993
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:156063.7576664505
# Sharpe:  0.2219181245626445
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:143864.77157420485
# Sharpe:  0.222768303096052
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:134641.03912753987
# Sharpe:  0.21255471883852411
# =================================
# reset at 2020-10-17T08:00:00.000000000
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 32            |
# |    iterations           | 24            |
# |    time_elapsed         | 1490          |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 2.2666063e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.1          |
# |    explained_variance   | 1.79e-06      |
# |    learning_rate        | 0.001         |
# |    loss                 | 7.32e+11      |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -3.71e-05     |
# |    std                  | 1             |
# |    value_loss           | 1.39e+12      |
# -------------------------------------------
# =================================
# begin_total_asset:10000
# end_total_asset:119170.2329320878
# Sharpe:  0.21103442911627776
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:131617.96118024524
# Sharpe:  0.21872743228661787
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:131728.99257628378
# Sharpe:  0.2165977826408879
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:131015.03759113706
# Sharpe:  0.21529691998673645
# =================================
# reset at 2020-10-17T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:136508.4267544389
# Sharpe:  0.21662349573257053
# =================================
# reset at 2020-10-17T08:00:00.000000000
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 32            |
# |    iterations           | 25            |
# |    time_elapsed         | 1551          |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 2.1900632e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.1          |
# |    explained_variance   | 2.03e-06      |
# |    learning_rate        | 0.001         |
# |    loss                 | 6.66e+11      |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -3.35e-05     |
# |    std                  | 1             |
# |    value_loss           | 1.54e+12      |
# -------------------------------------------
# reset at 2021-10-18T08:00:00.000000000
# reset at 2021-10-18T08:00:00.000000000
# =================================
# begin_total_asset:10000
# end_total_asset:14003.907963587597
# Sharpe:  0.03382247853992019
# =================================
# reset at 2021-10-18T08:00:00.000000000
# hit end!

# %%
from backtesting import *
# 讀取模型歷史每日投資組合權重和報酬率的檔案
df_daily_return = pd.read_csv(f'{FOLDER}df_daily_return_{AGENT_NAME}_crypto.csv', index_col=0, parse_dates=True)
df_actions = pd.read_csv(f'{FOLDER}df_actions_{AGENT_NAME}_crypto.csv', index_col=0, parse_dates=True)
# 讀取回測比較基準的資料
bm, close_data = prepare_backtesting_data(df_daily_return, df_actions, BENCHMARK, FOLDER)

# 限定資料頻率為8小時 (原本是頻率4小時)
bm = bm[bm.index.hour==8]
close_data = close_data[close_data.index.hour==8]

CASH = 10000
NAME = 'DRL Agent'
# 回測分析
backtest_analytics(df_daily_return, bm, df_actions, close_data, cash=CASH, NAME=NAME, BM_NAME=BENCHMARK)

# %% [markdown]
# # 回測結果
